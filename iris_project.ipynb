# %%
#Project 1
#Irina Vertiagina
#CIS 2541
#Summer 2025

# %%
from sklearn import datasets 
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np

# %%
# Load the Iris dataset
iris = datasets.load_iris()

# Convert to a Pandas DataFrame
iris_df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# Display the first few rows
print("First few rows of the dataset:")
print(iris_df.head())

# Display the last few rows
print("\nLast few rows of the dataset:")
print(iris_df.tail())
# Out:
# First few rows of the dataset:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
# Last few rows of the dataset:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# ...

# %% [markdown]
# ## Visualize the data

# %%
import seaborn as sns
# Add species column with names, not numeric codes
iris_df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# Create pairplot, coloring points by species
sns.pairplot(iris_df, height=1.5, hue="species");

# %%
# Split the data: 75% training, 25% testing (default)
X_train, X_test, y_train, y_test = train_test_split(
    iris.data, iris.target, random_state=42
)
# Print shapes
print("Training features shape:", X_train.shape)
print("Testing features shape:", X_test.shape)
# Out:
# Training features shape: (112, 4)
# Testing features shape: (38, 4)

# %% [markdown]
# ## kNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# predict
knn_preds = knn.predict(X_test)

# %% [markdown]
# ## Naive Bayes Model

# %%
from sklearn.naive_bayes import GaussianNB

nb = GaussianNB()
nb.fit(X_train, y_train)
# predict
nb_preds = nb.predict(X_test)

# %% [markdown]
# ## Compare models using F1 score

# %%
from sklearn.metrics import f1_score

knn_f1 = f1_score(y_test, knn_preds, average='macro')
nb_f1 = f1_score(y_test, nb_preds, average='macro')

print("kNN F1 score:", knn_f1)
print("Naive Bayes F1 score:", nb_f1)
# Out:
# kNN F1 score: 1.0
# Naive Bayes F1 score: 1.0
